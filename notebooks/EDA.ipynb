# %% [markdown]
# <h3><center><b>Lumina: Uso de Visão Computacional no Apoio ao Diagnóstico de Doenças Oculares</b><br>
# </center></h3>
#
# Este notebook apresenta uma metodologia para segmentar e classificar imagens de fundo de olho para detecção de doenças oculares, como resultado de Trabalho de Conclusão de Curso para obtenção de título de bacharel em Engenharia Elétrica na Universidade Federal do Ceará.
#
# **Autor:** Pedro Florencio de Almeida Neto - Cientista de Dados @Ipplan Fortaleza
#
# <i>pedroflorencio@alu.ufc.br</i>
